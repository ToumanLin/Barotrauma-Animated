# %% [markdown]
# ## 近期目标

# %% [markdown]
# * <font size=5>BUG&反馈</font>
#   - 耳机问题
# * <font size=5>跟进游戏更新</font>

# %% [markdown]
# * <font size=5>加入高跟</font>
#   - 未完成列表
#     - 母亲的怀抱
# * 脚步声
#
# * 加入脸型和有意思的东西
#
# * XDS
#   - 架子
#   - XDS打捞任务

# %% [markdown]
# - <font size=5>新的合成方式</font>
#   - **TapeWriter**: 使用*空白TAPE*, 打印*蓝图TAPE*
#     - 修改 TapeWriter 的可用配方？比如放入一个通行证来让TapeWriter可制作的Tape更多？
#     - 钥匙卡和补给箱
#       - 我在考虑用补给箱做类似‘抽盲盒‘的玩法。
#
#   - **ProcessBrench**: 这是合成台, 使用 *蓝图TAPE* 和 *素材* 生产 物品
#     - 需要一个关于所有合成配方的说明书
#       - 当然, 前提是我先把配方想出来
#     - 需要制作'耗材', 用于给ProcessBrench充能. 目前使用燃料罐充能.
#     - 通过Tape+素材的方式制作物品
#       - 需要做合成方式的物品有：
#         - 有些材料太后期了, 导致玩家在玩不到这些内容, 这应该要改变: <br> 我的想法是 **稀释压力稳定剂** (用来替代压力稳定剂作为合成材料), **PUCS Framework** (用来替代PUCS作为合成材料)
#         - 应该也要保持一些不通过*ProcessBrench* 合成的途径, 但是低效
#
#           | Item | Cost 1 | Cost 2|
#           |------|--------|--------|
#           | Exotic Matter| Serum | chitin,shellshield,mudraptorshell,molochbone,<br>hammerheadribs,endwormshell,watchershell,spinelingspikeloot|
#           | EPSP | TAPE | PUCS,pucs_framework |
#           | Cloth| TAPE | Underwear |
#
# - <font size=5>联络面板</font>
#   - 完成售卖物品的编写
#     - 是否应该考虑，在高声望时增加售卖物品的种类？
#   - 给联络面板增加贴图
#
# - <font size=5>头发</font>
#   - Biff认为应该加入更多头饰
#     - 哦我想要一个新的凯尔希猫耳
#   - 是否应该再加入更多后发的种类?
#
# - <font size=5>过去之恶</font>
#   - 重置 *EXO*
#   - 重置 *黑丝女仆*
#   - 重置 *职业制服*
#     - 安全官服 (1/2)
#   - 重置部分的 *cosplay*
#     - **Underwear**: 以后 cosplay 服装应该从 **ProcessBreench** 制作, 素材就是 *Underwear*
#       - 需要制作 '物品栏贴图' 和 '掉落贴图'
#     - 制作新的凯尔希制服
#     - 纯白流星（大工程）
# - <font size=5>其他</font>
#   - 兔女郎增加小丑服的多样性
#   - 制作*高级手持声纳* 的'贴图'
#   - 制作*激光瞄准器* 的'贴图"
#   - 制作一些 *诗集*
#
# - <font size=5>多余的和不知道怎么完成的</font>
#   - 一个船长帽
#   - 一个羽毛帽
#   - EMEXO
#   - HGIS
#   - 异星物质潜水服

# %% [markdown]
# ## 中期目标

# %% [markdown]
# - <font size=5>联动怪物娘化 </font>
#   - 给每种怪物都制作可以穿着的 cosplay服装
#   - cosplay服装升级成 '潜水服', 再升级成 'EPSP'
#   - 要考虑给不同的怪物服装设计不同的效果, 比如锤头鲨是不是应该有方式去撞人
# - <font size=5>新的武器和武器贴图重置</font>
#   - 武器贴图重置
#     - 手枪
#     - 其他
#   - 新的武器
#     - 能量饮料枪
# - <font size=5>对limb生效的医疗针</font>
#   - 这个东西还需要仔细考虑
# - <font size=5>分离主义者制服</font>
#   - 我认为按照 '共产主义' 风格制作这一系列的服装是恰当的
# - <font size=5>EAHI声望系统</font>
#   - 应该有随机事件获取或减少声望
#   - 应该有随机任务获取或减少声望
#   - 在低声望的时候应该有随机任务攻击玩家
#   - 这个系统应该要考虑到剧情

# %% [markdown]
# ## 远期目标
#
# 1. 主界面音乐和配图
# 2. 东亚重工剧情线，包含多结局
# 3. 新的职业

# %% [markdown]
# #### 东亚重工派系完善
#
# - 框架
#     - 联络面板
#         - 进一步完善
#         - 贴图
#     - 积分系统
#         - 通过任务获取积分
#         - 积分用途：生产图纸和钥匙卡 (抽奖券)；购买物品
#     - 声望系统
#         - 通过任务和随机事件获取声望
#         - 使用声望兑换积分
#     - 商人
#         - 回收商人: 回收物品给予积分
#         - 马克商人: 通用补给箱, 初级物品, 通用耗材
#         - 积分商人: 专用补给箱, 高级物品, 专用耗材
#     - [分解台]便携式增材制造机\
#         改成放置 -> 部署 的形式?
#         - 燃料: 电池
#         - 输入: 蓝图, 耗材 (通用, 专用)
#         - 输出: 物品
#     - [加工台]磁带打印机
#         - 使用积分和空白磁带 (联网情况下)制作生产蓝图
#         - 使用积分和空白钥匙卡 (联网情况下)制作
# - 血肉
#     - 任务系统
#         - 随机任务如运输船, 被劫持运输船, 更多任务种类
#     - 剧情
#         - 东亚重工的连贯剧情

# %% [markdown]
# | Limb Name        | SourceRect       | Origin     | Depth | SourceRect*Origin |
# |------------------|------------------|------------|-------|---------------------------------|
# | Head (1)         | 0,0,160,228      | 0.6125,0.33| 0.05  | (98.0, 75.24)                  |
# | Torso (0)        | 160,0,112,192    | 0.5,0.5    | 0.06  | (56.0, 96.0)                   |
# | Waist (12)       | 160,192,112,64   | 0.5,0.5    | 0.121 | (56.0, 32.0)                   |
# | RightArm (2)     | 272,0,64,96      | 0.5,0.5    | 0.02  | (32.0, 48.0)                   |
# | RightForearm (14)| 272,96,64,64     | 0.5,0.5    | 0.01  | (32.0, 32.0)                   |
# | RightHand (3)    | 272,160,64,48    | 0.44,0.4   | 0.015 | (28.16, 19.2)                  |
# | LeftArm (4)      | 336,0,64,96      | 0.5,0.5    | 0.14  | (32.0, 48.0)                   |
# | LeftForearm (13) | 336,96,64,64     | 0.5,0.5    | 0.15  | (32.0, 32.0)                   |
# | LeftHand (5)     | 336,160,64,48    | 0.44,0.4   | 0.16  | (28.16, 19.2)                  |
# | RightThigh (9)   | 0,0,80,128       | 0.5,0.5    | 0.12  | (40.0, 64.0)                   |
# | RightLeg (10)    | 0,128,80,128     | 0.5,0.5    | 0.121 | (40.0, 64.0)                   |
# | RightFoot (11)   | 272,208,64,48    | 0.48,0.55  | 0.122 | (30.72, 26.4)                  |
# | LeftThigh (6)    | 80,0,80,128      | 0.5,0.5    | 0.13  | (40.0, 64.0)                   |
# | LeftLeg (7)      | 80,128,80,128    | 0.5,0.5    | 0.131 | (40.0, 64.0)                   |
# | LeftFoot (8)     | 336,208,64,48    | 0.48,0.55  | 0.132 | (30.72, 26.4)                  |
# | LeftLeg (7)      | 80,128,80,128    | 0.5,0.5    | 0.131 | (40.0, 64.0)                   |
# | Hair             | 0,0,240,480      | 0.6125,0.3229  | N/A | (147, 155)                   |

# %% [markdown]
# |Limb |旋转角度|
# |-----|-------|
# |大腿 | 2.3   |
# |小腿 | -3.58  |
# |身体 | -2.00  |
# |大臂 | -3.30    |
# |小臂 | 2.7   |
# |放大比例- 身体 | 14.78%|
# |放大比例- 头 | 29.56%|
